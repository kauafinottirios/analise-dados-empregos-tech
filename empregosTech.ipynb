# %% [markdown]
# # Compreensão e Preparação dos dados
# ---

# %% [markdown]
# ## Importação e reconhecimento da base de dados

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
print(f"linhas: {df.shape[0]}, colunas: {df.shape[1]}\n")
df.info()
df.describe()
# Out:
# linhas: 133349, colunas: 11
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB
#            work_year        salary  salary_in_usd   remote_ratio
# ...

# %% [markdown]
# ## Renomeando as colunas para fácilitar a compreensão

# %%
novos_nomes_colunas = {
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'tipo_contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'}

df.rename(columns=novos_nomes_colunas, inplace=True)

df.head()
# Out:
#       ano senioridade tipo_contrato               cargo  salario moeda  \
# 0  2025.0          SE            FT  Solutions Engineer   214000   USD
# 1  2025.0          SE            FT  Solutions Engineer   136000   USD
# 2  2025.0          MI            FT       Data Engineer   158800   USD
# 3  2025.0          MI            FT       Data Engineer   139200   USD
# 4  2025.0          EN            FT       Data Engineer    90000   USD
#
#       usd residencia  remoto empresa tamanho_empresa
# 0  214000         US     100      US               M
# 1  136000         US     100      US               M
# 2  158800         AU       0      AU               M
# 3  139200         AU       0      AU               M
# 4   90000         US       0      US               M

# %% [markdown]
# ## Renomeando os valores para fácilitar a compreensão

# %%
senioridade = {
    'SE': 'senior',
    'MI': 'pleno',
    'EN': 'junior',
    'EX': 'executivo'}

contrato = {
    'FT': 'integral',
    'PT': 'parcial',
    'CT': 'contrato',
    'FL': 'freelancer'}

tamanho_empresa = {
    'L': 'grande',
    'S': 'pequena',
    'M': 'media'}

mapa_trabalho = {
    0: 'presencial',
    100: 'remoto',
    50: 'hibrido'}

df['senioridade'] = df['senioridade'].replace(senioridade) 
df['tipo_contrato'] = df['tipo_contrato'].replace(contrato)
df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa)
df['remoto'] = df['remoto'].replace(mapa_trabalho)

df.head()
# Out:
#       ano senioridade tipo_contrato               cargo  salario moeda  \
# 0  2025.0      senior      integral  Solutions Engineer   214000   USD
# 1  2025.0      senior      integral  Solutions Engineer   136000   USD
# 2  2025.0       pleno      integral       Data Engineer   158800   USD
# 3  2025.0       pleno      integral       Data Engineer   139200   USD
# 4  2025.0      junior      integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      remoto      US           media
# 1  136000         US      remoto      US           media
# 2  158800         AU  presencial      AU           media
# 3  139200         AU  presencial      AU           media
# 4   90000         US  presencial      US           media

# %% [markdown]
# # Tratamento dos dados
# ---

# %% [markdown]
# ## Remoção das linhas com valores nulos
# Uma vez que foi descoberta que na base de dados de 133349 linhas havia apenas 10 linhas que apresentavam valores ``NaN``, uma quantia ínfima perto da quantidade total, optou-se por remover essas linhas.

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade tipo_contrato                      cargo  salario  \
# 5588    NaN      senior      integral            Product Manager   184500
# 59692   NaN       pleno      integral                   Engineer   110000
# 59710   NaN      junior      integral             Data Scientist   208800
# 59759   NaN      senior      integral          Software Engineer   135000
# 59789   NaN      senior      integral                   Engineer   112000
# 131000  NaN      senior      integral  Machine Learning Engineer   163800
# 131006  NaN      senior      integral     Data Analytics Manager   204500
# 133054  NaN      junior      integral             Data Scientist    40000
# 133281  NaN       pleno      integral  Machine Learning Engineer   180000
# 133317  NaN       pleno      integral             Data Scientist   130000
#
#        moeda     usd residencia      remoto empresa tamanho_empresa
# 5588     USD  184500         US  presencial      US           media
# ...

# %%
df_limpo = df.dropna()

df_limpo.isnull().sum()
# Out:
# ano                0
# senioridade        0
# tipo_contrato      0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %% [markdown]
# ## Alteração do tipo de dados
# Optou-se por converter o tipo de dados da coluna "ano" de `float64` para `int64`, pois é mais condizente em se tratatando do tipo de dado que a coluna apresenta.

# %%
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('Int64'))
df_limpo.head()
# Out:
#     ano senioridade tipo_contrato               cargo  salario moeda     usd  \
# 0  2025      senior      integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior      integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno      integral       Data Engineer   158800   USD  158800
# 3  2025       pleno      integral       Data Engineer   139200   USD  139200
# 4  2025      junior      integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %% [markdown]
# # Visualização dos dados
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import pycountry

# %%
ordem = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=True).index

plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='senioridade', y='usd', order=ordem)
plt.title("Salário médio por senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário médio anual (USD)")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(df_limpo['usd'], bins = 50, kde=True)
plt.title("Distribuição dos salários anuais")
plt.xlabel("Salário em USD")
plt.ylabel("Frequência")
plt.show()

# %%
ordem_senioridade = ['junior', 'pleno', 'senior', 'executivo']

plt.figure(figsize=(8,5))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade, palette='Set2', hue='senioridade')
plt.title("Boxplot da distribuição por senioridade")
plt.xlabel("Salário em USD")
plt.show()

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho',
             hole=0.5
          )
fig.update_traces(textinfo='percent+label')
fig.show()

# %%
# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()

# %%
#Salvar a base de dados tratada em um arquivo csv.
df_limpo.to_csv('dados-imersao-final.csv', index=False)
